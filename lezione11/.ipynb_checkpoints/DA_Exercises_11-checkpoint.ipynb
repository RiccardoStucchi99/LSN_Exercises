# %% [markdown]
# ### Exercise 11.1
#
# In order to make practice with NN, explore how does the previous linear regression depend on the number of epochs, $N_{\mathrm{epochs}}$, the number of data points $N_{\mathrm{train}}$ and on the noise $\sigma$. Try to improve the previous result operating on these parameters.

# %% [markdown]
# ### Comment:
# In the exercise a simple neural network consisting of only one neuron is used to fit the function $y=2x+1$.
# The neuron output, as showed in the network summary, depends from two parameters that need to be optimized so that given an input $x$, the output is as close as possible to $2x+1$.
#
# Let's start considering the case $\sigma=0$. By varying the number of epochs $N_{\mathrm{epochs}}$ and the number of data points $N_{\mathrm{train}}$ we can get an intuition about how the neuron learns. The initial parameters are presumably chosen at random, then they are optimized through an optimization algorythm ('SGD' in this case). The optimization can be improved in two ways: 1) by increasing $N_{\mathrm{train}}$ we give the neuron more points to learn from; 2) with larger $N_{\mathrm{epochs}}$ we increase the number of times the neuron can learn from a given set.
# To clarify, it is like studying something from many different books (1st method, diversification) compared to studying something by reading over and over the same book (2nd method, intensification).
#
# While for the simple task of linear fitting without noise both methods can be applied almost exclusively, the situation is more complicated even for slightly more complicated tasks such as the linear fit with noise. In fact, when the $\sigma$ is not equal to zero and $N_{\mathrm{train}}$ is small, if we increase $N_{\mathrm{epochs}}$ we might overfit the data. On the contrary, with large $N_{\mathrm{train}}$ we risk to underfit the data unless we hugely increase $N_{\mathrm{epochs}}$. Hence, for an efficient learning we should balance $N_{\mathrm{epochs}}$ and $N_{\mathrm{train}}$.

# %%
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect

# %% [markdown]
# ### Generating sets of data for training and validation

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 100)
x_valid = np.random.uniform(-1, 1, 1000)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 1 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# %%
# plot validation and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target, label='target')
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### One neuron sequential model

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# get a summary of our composed model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ###  Fitting model

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=300,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/300
# 4/4 [==============================] - 0s 29ms/step - loss: 5.1909 - mse: 5.1909 - val_loss: 5.8747 - val_mse: 5.8747
# Epoch 2/300
# 4/4 [==============================] - 0s 7ms/step - loss: 4.9270 - mse: 4.9270 - val_loss: 5.6266 - val_mse: 5.6266
# Epoch 3/300
# 4/4 [==============================] - 0s 7ms/step - loss: 4.7198 - mse: 4.7198 - val_loss: 5.3466 - val_mse: 5.3466
# Epoch 4/300
# 4/4 [==============================] - 0s 7ms/step - loss: 4.4904 - mse: 4.4904 - val_loss: 5.0217 - val_mse: 5.0217
# Epoch 5/300
# 4/4 [==============================] - 0s 8ms/step - loss: 4.2323 - mse: 4.2323 - val_loss: 4.8145 - val_mse: 4.8145
# Epoch 6/300
# 4/4 [==============================] - 0s 8ms/step - loss: 4.0593 - mse: 4.0593 - val_loss: 4.6253 - val_mse: 4.6253
# Epoch 7/300
# 4/4 [==============================] - 0s 8ms/step - loss: 3.9083 - mse: 3.9083 - val_loss: 4.4469 - val_mse: 4.4469
# Epoch 8/300
# 4/4 [==============================] - 0s 8ms/step - loss: 3.7566 - mse: 3.7566 - val_loss: 4.1945 - val_mse: 4.1945
# Epoch 9/300
# 4/4 [==============================] - 0s 8ms/step - loss: 3.5610 - mse: 3.5610 - val_loss: 4.0661 - val_mse: 4.0661
# Epoch 10/300
# 4/4 [==============================] - 0s 8ms/step - loss: 3.4498 - mse: 3.4498 - val_loss: 3.8436 - val_mse: 3.8436
# Epoch 11/300
# 4/4 [==============================] - 0s 7ms/step - loss: 3.2766 - mse: 3.2766 - val_loss: 3.7229 - val_mse: 3.7229
# Epoch 12/300
# 4/4 [==============================] - 0s 8ms/step - loss: 3.1824 - mse: 3.1824 - val_loss: 3.5884 - val_mse: 3.5884
# Epoch 13/300
# 4/4 [==============================] - 0s 7ms/step - loss: 3.0761 - mse: 3.0761 - val_loss: 3.4736 - val_mse: 3.4736
# Epoch 14/300
# 4/4 [==============================] - 0s 7ms/step - loss: 2.9814 - mse: 2.9814 - val_loss: 3.3177 - val_mse: 3.3177
# Epoch 15/300
# 4/4 [==============================] - 0s 7ms/step - loss: 2.8598 - mse: 2.8598 - val_loss: 3.1979 - val_mse: 3.1979
# Epoch 16/300
# 4/4 [==============================] - 0s 8ms/step - loss: 2.7662 - mse: 2.7662 - val_loss: 3.0993 - val_mse: 3.0993
# Epoch 17/300
# 4/4 [==============================] - 0s 7ms/step - loss: 2.6867 - mse: 2.6867 - val_loss: 2.9795 - val_mse: 2.9795
# Epoch 18/300
# 4/4 [==============================] - 0s 8ms/step - loss: 2.5965 - mse: 2.5965 - val_loss: 2.8744 - val_mse: 2.8744
# Epoch 19/300
# 4/4 [==============================] - 0s 7ms/step - loss: 2.5156 - mse: 2.5156 - val_loss: 2.8028 - val_mse: 2.8028
# Epoch 20/300
# 4/4 [==============================] - 0s 7ms/step - loss: 2.4512 - mse: 2.4512 - val_loss: 2.7242 - val_mse: 2.7242
# Epoch 21/300
# 4/4 [==============================] - 0s 8ms/step - loss: 2.3876 - mse: 2.3876 - val_loss: 2.6379 - val_mse: 2.6379
# Epoch 22/300
# 4/4 [==============================] - 0s 7ms/step - loss: 2.3197 - mse: 2.3197 - val_loss: 2.5513 - val_mse: 2.5513
# Epoch 23/300
# 4/4 [==============================] - 0s 8ms/step - loss: 2.2515 - mse: 2.2515 - val_loss: 2.4844 - val_mse: 2.4844
# Epoch 24/300
# 4/4 [==============================] - 0s 7ms/step - loss: 2.1902 - mse: 2.1902 - val_loss: 2.4181 - val_mse: 2.4181
# Epoch 25/300
# 4/4 [==============================] - 0s 7ms/step - loss: 2.1352 - mse: 2.1352 - val_loss: 2.3512 - val_mse: 2.3512
# Epoch 26/300
# 4/4 [==============================] - 0s 8ms/step - loss: 2.0821 - mse: 2.0821 - val_loss: 2.2816 - val_mse: 2.2816
# Epoch 27/300
# 4/4 [==============================] - 0s 8ms/step - loss: 2.0311 - mse: 2.0311 - val_loss: 2.2064 - val_mse: 2.2064
# Epoch 28/300
# 4/4 [==============================] - 0s 8ms/step - loss: 1.9708 - mse: 1.9708 - val_loss: 2.1491 - val_mse: 2.1491
# Epoch 29/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9273 - mse: 1.9273 - val_loss: 2.0928 - val_mse: 2.0928
# Epoch 30/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.8824 - mse: 1.8824 - val_loss: 2.0419 - val_mse: 2.0419
# Epoch 31/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.8351 - mse: 1.8351 - val_loss: 1.9946 - val_mse: 1.9946
# Epoch 32/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.7931 - mse: 1.7931 - val_loss: 1.9421 - val_mse: 1.9421
# Epoch 33/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.7554 - mse: 1.7554 - val_loss: 1.8986 - val_mse: 1.8986
# Epoch 34/300
# 4/4 [==============================] - 0s 8ms/step - loss: 1.7229 - mse: 1.7229 - val_loss: 1.8626 - val_mse: 1.8626
# Epoch 35/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.6893 - mse: 1.6893 - val_loss: 1.8203 - val_mse: 1.8203
# Epoch 36/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.6568 - mse: 1.6568 - val_loss: 1.7816 - val_mse: 1.7816
# Epoch 37/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.6177 - mse: 1.6177 - val_loss: 1.7479 - val_mse: 1.7479
# Epoch 38/300
# 4/4 [==============================] - 0s 8ms/step - loss: 1.5884 - mse: 1.5884 - val_loss: 1.7060 - val_mse: 1.7060
# Epoch 39/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.5553 - mse: 1.5553 - val_loss: 1.6750 - val_mse: 1.6750
# Epoch 40/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.5332 - mse: 1.5332 - val_loss: 1.6379 - val_mse: 1.6379
# Epoch 41/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.5021 - mse: 1.5021 - val_loss: 1.6102 - val_mse: 1.6102
# Epoch 42/300
# 4/4 [==============================] - 0s 8ms/step - loss: 1.4808 - mse: 1.4808 - val_loss: 1.5756 - val_mse: 1.5756
# Epoch 43/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.4569 - mse: 1.4569 - val_loss: 1.5449 - val_mse: 1.5449
# Epoch 44/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.4302 - mse: 1.4302 - val_loss: 1.5048 - val_mse: 1.5048
# Epoch 45/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.4022 - mse: 1.4022 - val_loss: 1.4761 - val_mse: 1.4761
# Epoch 46/300
# 4/4 [==============================] - 0s 8ms/step - loss: 1.3855 - mse: 1.3855 - val_loss: 1.4534 - val_mse: 1.4534
# Epoch 47/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3633 - mse: 1.3633 - val_loss: 1.4274 - val_mse: 1.4274
# Epoch 48/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3480 - mse: 1.3480 - val_loss: 1.4121 - val_mse: 1.4121
# Epoch 49/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3354 - mse: 1.3354 - val_loss: 1.3893 - val_mse: 1.3893
# Epoch 50/300
# 4/4 [==============================] - 0s 8ms/step - loss: 1.3184 - mse: 1.3184 - val_loss: 1.3691 - val_mse: 1.3691
# Epoch 51/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3035 - mse: 1.3035 - val_loss: 1.3590 - val_mse: 1.3590
# Epoch 52/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.2922 - mse: 1.2922 - val_loss: 1.3407 - val_mse: 1.3407
# Epoch 53/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.2801 - mse: 1.2801 - val_loss: 1.3283 - val_mse: 1.3283
# Epoch 54/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.2693 - mse: 1.2693 - val_loss: 1.3077 - val_mse: 1.3077
# Epoch 55/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.2589 - mse: 1.2589 - val_loss: 1.2928 - val_mse: 1.2928
# Epoch 56/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.2476 - mse: 1.2476 - val_loss: 1.2817 - val_mse: 1.2817
# Epoch 57/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.2363 - mse: 1.2363 - val_loss: 1.2643 - val_mse: 1.2643
# Epoch 58/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.2244 - mse: 1.2244 - val_loss: 1.2527 - val_mse: 1.2527
# Epoch 59/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.2150 - mse: 1.2150 - val_loss: 1.2435 - val_mse: 1.2435
# Epoch 60/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.2076 - mse: 1.2076 - val_loss: 1.2318 - val_mse: 1.2318
# Epoch 61/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1982 - mse: 1.1982 - val_loss: 1.2158 - val_mse: 1.2158
# Epoch 62/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1940 - mse: 1.1940 - val_loss: 1.2117 - val_mse: 1.2117
# Epoch 63/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1870 - mse: 1.1870 - val_loss: 1.1949 - val_mse: 1.1949
# Epoch 64/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1780 - mse: 1.1780 - val_loss: 1.1872 - val_mse: 1.1872
# Epoch 65/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1706 - mse: 1.1706 - val_loss: 1.1785 - val_mse: 1.1785
# Epoch 66/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1650 - mse: 1.1650 - val_loss: 1.1712 - val_mse: 1.1712
# Epoch 67/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1627 - mse: 1.1627 - val_loss: 1.1621 - val_mse: 1.1621
# Epoch 68/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1548 - mse: 1.1548 - val_loss: 1.1481 - val_mse: 1.1481
# Epoch 69/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1467 - mse: 1.1467 - val_loss: 1.1417 - val_mse: 1.1417
# Epoch 70/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1432 - mse: 1.1432 - val_loss: 1.1374 - val_mse: 1.1374
# Epoch 71/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1404 - mse: 1.1404 - val_loss: 1.1259 - val_mse: 1.1259
# Epoch 72/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1323 - mse: 1.1323 - val_loss: 1.1178 - val_mse: 1.1178
# Epoch 73/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1291 - mse: 1.1291 - val_loss: 1.1061 - val_mse: 1.1061
# Epoch 74/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1240 - mse: 1.1240 - val_loss: 1.0953 - val_mse: 1.0953
# Epoch 75/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1167 - mse: 1.1167 - val_loss: 1.0894 - val_mse: 1.0894
# Epoch 76/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1094 - mse: 1.1094 - val_loss: 1.0853 - val_mse: 1.0853
# Epoch 77/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1064 - mse: 1.1064 - val_loss: 1.0737 - val_mse: 1.0737
# Epoch 78/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1005 - mse: 1.1005 - val_loss: 1.0702 - val_mse: 1.0702
# Epoch 79/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0994 - mse: 1.0994 - val_loss: 1.0682 - val_mse: 1.0682
# Epoch 80/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0972 - mse: 1.0972 - val_loss: 1.0599 - val_mse: 1.0599
# Epoch 81/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0936 - mse: 1.0936 - val_loss: 1.0577 - val_mse: 1.0577
# Epoch 82/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0911 - mse: 1.0911 - val_loss: 1.0575 - val_mse: 1.0575
# Epoch 83/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0903 - mse: 1.0903 - val_loss: 1.0488 - val_mse: 1.0488
# Epoch 84/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0871 - mse: 1.0871 - val_loss: 1.0501 - val_mse: 1.0501
# Epoch 85/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0878 - mse: 1.0878 - val_loss: 1.0505 - val_mse: 1.0505
# Epoch 86/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0842 - mse: 1.0842 - val_loss: 1.0449 - val_mse: 1.0449
# Epoch 87/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0829 - mse: 1.0829 - val_loss: 1.0448 - val_mse: 1.0448
# Epoch 88/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0808 - mse: 1.0808 - val_loss: 1.0418 - val_mse: 1.0418
# Epoch 89/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0802 - mse: 1.0802 - val_loss: 1.0340 - val_mse: 1.0340
# Epoch 90/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0752 - mse: 1.0752 - val_loss: 1.0328 - val_mse: 1.0328
# Epoch 91/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0748 - mse: 1.0748 - val_loss: 1.0259 - val_mse: 1.0259
# Epoch 92/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0728 - mse: 1.0728 - val_loss: 1.0261 - val_mse: 1.0261
# Epoch 93/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0716 - mse: 1.0716 - val_loss: 1.0218 - val_mse: 1.0218
# Epoch 94/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0695 - mse: 1.0695 - val_loss: 1.0163 - val_mse: 1.0163
# Epoch 95/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0689 - mse: 1.0689 - val_loss: 1.0162 - val_mse: 1.0162
# Epoch 96/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0672 - mse: 1.0672 - val_loss: 1.0153 - val_mse: 1.0153
# Epoch 97/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0687 - mse: 1.0687 - val_loss: 1.0167 - val_mse: 1.0167
# Epoch 98/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0675 - mse: 1.0675 - val_loss: 1.0131 - val_mse: 1.0131
# Epoch 99/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0687 - mse: 1.0687 - val_loss: 1.0119 - val_mse: 1.0119
# Epoch 100/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0663 - mse: 1.0663 - val_loss: 1.0109 - val_mse: 1.0109
# Epoch 101/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0653 - mse: 1.0653 - val_loss: 1.0076 - val_mse: 1.0076
# Epoch 102/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0650 - mse: 1.0650 - val_loss: 1.0046 - val_mse: 1.0046
# Epoch 103/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0635 - mse: 1.0635 - val_loss: 1.0012 - val_mse: 1.0012
# Epoch 104/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0627 - mse: 1.0627 - val_loss: 0.9992 - val_mse: 0.9992
# Epoch 105/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0610 - mse: 1.0610 - val_loss: 0.9978 - val_mse: 0.9978
# Epoch 106/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0610 - mse: 1.0610 - val_loss: 0.9931 - val_mse: 0.9931
# Epoch 107/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0593 - mse: 1.0593 - val_loss: 0.9884 - val_mse: 0.9884
# Epoch 108/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0582 - mse: 1.0582 - val_loss: 0.9900 - val_mse: 0.9900
# Epoch 109/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0580 - mse: 1.0580 - val_loss: 0.9891 - val_mse: 0.9891
# Epoch 110/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0580 - mse: 1.0580 - val_loss: 0.9839 - val_mse: 0.9839
# Epoch 111/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0572 - mse: 1.0572 - val_loss: 0.9846 - val_mse: 0.9846
# Epoch 112/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0560 - mse: 1.0560 - val_loss: 0.9830 - val_mse: 0.9830
# Epoch 113/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0552 - mse: 1.0552 - val_loss: 0.9815 - val_mse: 0.9815
# Epoch 114/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0542 - mse: 1.0542 - val_loss: 0.9799 - val_mse: 0.9799
# Epoch 115/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0533 - mse: 1.0533 - val_loss: 0.9795 - val_mse: 0.9795
# Epoch 116/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0527 - mse: 1.0527 - val_loss: 0.9783 - val_mse: 0.9783
# Epoch 117/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0512 - mse: 1.0512 - val_loss: 0.9773 - val_mse: 0.9773
# Epoch 118/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0510 - mse: 1.0510 - val_loss: 0.9788 - val_mse: 0.9788
# Epoch 119/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0510 - mse: 1.0510 - val_loss: 0.9779 - val_mse: 0.9779
# Epoch 120/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0516 - mse: 1.0516 - val_loss: 0.9787 - val_mse: 0.9787
# Epoch 121/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0498 - mse: 1.0498 - val_loss: 0.9788 - val_mse: 0.9788
# Epoch 122/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0499 - mse: 1.0499 - val_loss: 0.9807 - val_mse: 0.9807
# Epoch 123/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0497 - mse: 1.0497 - val_loss: 0.9802 - val_mse: 0.9802
# Epoch 124/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0491 - mse: 1.0491 - val_loss: 0.9785 - val_mse: 0.9785
# Epoch 125/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0486 - mse: 1.0486 - val_loss: 0.9746 - val_mse: 0.9746
# Epoch 126/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0485 - mse: 1.0485 - val_loss: 0.9739 - val_mse: 0.9739
# Epoch 127/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0481 - mse: 1.0481 - val_loss: 0.9724 - val_mse: 0.9724
# Epoch 128/300
# 4/4 [==============================] - 0s 8ms/step - loss: 1.0481 - mse: 1.0481 - val_loss: 0.9742 - val_mse: 0.9742
# Epoch 129/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0479 - mse: 1.0479 - val_loss: 0.9755 - val_mse: 0.9755
# Epoch 130/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0480 - mse: 1.0480 - val_loss: 0.9801 - val_mse: 0.9801
# Epoch 131/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0492 - mse: 1.0492 - val_loss: 0.9804 - val_mse: 0.9804
# Epoch 132/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0483 - mse: 1.0483 - val_loss: 0.9748 - val_mse: 0.9748
# Epoch 133/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0485 - mse: 1.0485 - val_loss: 0.9800 - val_mse: 0.9800
# Epoch 134/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0485 - mse: 1.0485 - val_loss: 0.9777 - val_mse: 0.9777
# Epoch 135/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0484 - mse: 1.0484 - val_loss: 0.9794 - val_mse: 0.9794
# Epoch 136/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0483 - mse: 1.0483 - val_loss: 0.9774 - val_mse: 0.9774
# Epoch 137/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0476 - mse: 1.0476 - val_loss: 0.9713 - val_mse: 0.9713
# Epoch 138/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0466 - mse: 1.0466 - val_loss: 0.9737 - val_mse: 0.9737
# Epoch 139/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0470 - mse: 1.0470 - val_loss: 0.9733 - val_mse: 0.9733
# Epoch 140/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0471 - mse: 1.0471 - val_loss: 0.9712 - val_mse: 0.9712
# Epoch 141/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0471 - mse: 1.0471 - val_loss: 0.9642 - val_mse: 0.9642
# Epoch 142/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0469 - mse: 1.0469 - val_loss: 0.9650 - val_mse: 0.9650
# Epoch 143/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0463 - mse: 1.0463 - val_loss: 0.9640 - val_mse: 0.9640
# Epoch 144/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0475 - mse: 1.0475 - val_loss: 0.9627 - val_mse: 0.9627
# Epoch 145/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0466 - mse: 1.0466 - val_loss: 0.9657 - val_mse: 0.9657
# Epoch 146/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0461 - mse: 1.0461 - val_loss: 0.9671 - val_mse: 0.9671
# Epoch 147/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0458 - mse: 1.0458 - val_loss: 0.9688 - val_mse: 0.9688
# Epoch 148/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0461 - mse: 1.0461 - val_loss: 0.9679 - val_mse: 0.9679
# Epoch 149/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0462 - mse: 1.0462 - val_loss: 0.9663 - val_mse: 0.9663
# Epoch 150/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0464 - mse: 1.0464 - val_loss: 0.9653 - val_mse: 0.9653
# Epoch 151/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0460 - mse: 1.0460 - val_loss: 0.9656 - val_mse: 0.9656
# Epoch 152/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0466 - mse: 1.0466 - val_loss: 0.9655 - val_mse: 0.9655
# Epoch 153/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0462 - mse: 1.0462 - val_loss: 0.9654 - val_mse: 0.9654
# Epoch 154/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0459 - mse: 1.0459 - val_loss: 0.9648 - val_mse: 0.9648
# Epoch 155/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0460 - mse: 1.0460 - val_loss: 0.9619 - val_mse: 0.9619
# Epoch 156/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0451 - mse: 1.0451 - val_loss: 0.9618 - val_mse: 0.9618
# Epoch 157/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0456 - mse: 1.0456 - val_loss: 0.9604 - val_mse: 0.9604
# Epoch 158/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0458 - mse: 1.0458 - val_loss: 0.9583 - val_mse: 0.9583
# Epoch 159/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0488 - mse: 1.0488 - val_loss: 0.9579 - val_mse: 0.9579
# Epoch 160/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0468 - mse: 1.0468 - val_loss: 0.9587 - val_mse: 0.9587
# Epoch 161/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0452 - mse: 1.0452 - val_loss: 0.9589 - val_mse: 0.9589
# Epoch 162/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0458 - mse: 1.0458 - val_loss: 0.9575 - val_mse: 0.9575
# Epoch 163/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0446 - mse: 1.0446 - val_loss: 0.9560 - val_mse: 0.9560
# Epoch 164/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0443 - mse: 1.0443 - val_loss: 0.9557 - val_mse: 0.9557
# Epoch 165/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0446 - mse: 1.0446 - val_loss: 0.9553 - val_mse: 0.9553
# Epoch 166/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0444 - mse: 1.0444 - val_loss: 0.9569 - val_mse: 0.9569
# Epoch 167/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0446 - mse: 1.0446 - val_loss: 0.9596 - val_mse: 0.9596
# Epoch 168/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0442 - mse: 1.0442 - val_loss: 0.9577 - val_mse: 0.9577
# Epoch 169/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0453 - mse: 1.0453 - val_loss: 0.9627 - val_mse: 0.9627
# Epoch 170/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0446 - mse: 1.0446 - val_loss: 0.9605 - val_mse: 0.9605
# Epoch 171/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0447 - mse: 1.0447 - val_loss: 0.9644 - val_mse: 0.9644
# Epoch 172/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0453 - mse: 1.0453 - val_loss: 0.9659 - val_mse: 0.9659
# Epoch 173/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0453 - mse: 1.0453 - val_loss: 0.9679 - val_mse: 0.9679
# Epoch 174/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0459 - mse: 1.0459 - val_loss: 0.9681 - val_mse: 0.9681
# Epoch 175/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0459 - mse: 1.0459 - val_loss: 0.9709 - val_mse: 0.9709
# Epoch 176/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0469 - mse: 1.0469 - val_loss: 0.9712 - val_mse: 0.9712
# Epoch 177/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0465 - mse: 1.0465 - val_loss: 0.9673 - val_mse: 0.9673
# Epoch 178/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0460 - mse: 1.0460 - val_loss: 0.9663 - val_mse: 0.9663
# Epoch 179/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0455 - mse: 1.0455 - val_loss: 0.9641 - val_mse: 0.9641
# Epoch 180/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0449 - mse: 1.0449 - val_loss: 0.9682 - val_mse: 0.9682
# Epoch 181/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0459 - mse: 1.0459 - val_loss: 0.9733 - val_mse: 0.9733
# Epoch 182/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0475 - mse: 1.0475 - val_loss: 0.9684 - val_mse: 0.9684
# Epoch 183/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0470 - mse: 1.0470 - val_loss: 0.9679 - val_mse: 0.9679
# Epoch 184/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0461 - mse: 1.0461 - val_loss: 0.9698 - val_mse: 0.9698
# Epoch 185/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0467 - mse: 1.0467 - val_loss: 0.9705 - val_mse: 0.9705
# Epoch 186/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0466 - mse: 1.0466 - val_loss: 0.9704 - val_mse: 0.9704
# Epoch 187/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0467 - mse: 1.0467 - val_loss: 0.9654 - val_mse: 0.9654
# Epoch 188/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0456 - mse: 1.0456 - val_loss: 0.9637 - val_mse: 0.9637
# Epoch 189/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0450 - mse: 1.0450 - val_loss: 0.9627 - val_mse: 0.9627
# Epoch 190/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0455 - mse: 1.0455 - val_loss: 0.9629 - val_mse: 0.9629
# Epoch 191/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0447 - mse: 1.0447 - val_loss: 0.9602 - val_mse: 0.9602
# Epoch 192/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0456 - mse: 1.0456 - val_loss: 0.9578 - val_mse: 0.9578
# Epoch 193/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0447 - mse: 1.0447 - val_loss: 0.9591 - val_mse: 0.9591
# Epoch 194/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0450 - mse: 1.0450 - val_loss: 0.9576 - val_mse: 0.9576
# Epoch 195/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0446 - mse: 1.0446 - val_loss: 0.9592 - val_mse: 0.9592
# Epoch 196/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0443 - mse: 1.0443 - val_loss: 0.9610 - val_mse: 0.9610
# Epoch 197/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0445 - mse: 1.0445 - val_loss: 0.9610 - val_mse: 0.9610
# Epoch 198/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0449 - mse: 1.0449 - val_loss: 0.9590 - val_mse: 0.9590
# Epoch 199/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0441 - mse: 1.0441 - val_loss: 0.9582 - val_mse: 0.9582
# Epoch 200/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0437 - mse: 1.0437 - val_loss: 0.9565 - val_mse: 0.9565
# Epoch 201/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0436 - mse: 1.0436 - val_loss: 0.9548 - val_mse: 0.9548
# Epoch 202/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0436 - mse: 1.0436 - val_loss: 0.9569 - val_mse: 0.9569
# Epoch 203/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0441 - mse: 1.0441 - val_loss: 0.9579 - val_mse: 0.9579
# Epoch 204/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0447 - mse: 1.0447 - val_loss: 0.9576 - val_mse: 0.9576
# Epoch 205/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0438 - mse: 1.0438 - val_loss: 0.9614 - val_mse: 0.9614
# Epoch 206/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0445 - mse: 1.0445 - val_loss: 0.9585 - val_mse: 0.9585
# Epoch 207/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0440 - mse: 1.0440 - val_loss: 0.9538 - val_mse: 0.9538
# Epoch 208/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0437 - mse: 1.0437 - val_loss: 0.9519 - val_mse: 0.9519
# Epoch 209/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0436 - mse: 1.0436 - val_loss: 0.9523 - val_mse: 0.9523
# Epoch 210/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0436 - mse: 1.0436 - val_loss: 0.9562 - val_mse: 0.9562
# Epoch 211/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0443 - mse: 1.0443 - val_loss: 0.9515 - val_mse: 0.9515
# Epoch 212/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0441 - mse: 1.0441 - val_loss: 0.9525 - val_mse: 0.9525
# Epoch 213/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0440 - mse: 1.0440 - val_loss: 0.9519 - val_mse: 0.9519
# Epoch 214/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0436 - mse: 1.0436 - val_loss: 0.9521 - val_mse: 0.9521
# Epoch 215/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0461 - mse: 1.0461 - val_loss: 0.9517 - val_mse: 0.9517
# Epoch 216/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0460 - mse: 1.0460 - val_loss: 0.9547 - val_mse: 0.9547
# Epoch 217/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0442 - mse: 1.0442 - val_loss: 0.9563 - val_mse: 0.9563
# Epoch 218/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0451 - mse: 1.0451 - val_loss: 0.9530 - val_mse: 0.9530
# Epoch 219/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0446 - mse: 1.0446 - val_loss: 0.9469 - val_mse: 0.9469
# Epoch 220/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0449 - mse: 1.0449 - val_loss: 0.9453 - val_mse: 0.9453
# Epoch 221/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0433 - mse: 1.0433 - val_loss: 0.9455 - val_mse: 0.9455
# Epoch 222/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0443 - mse: 1.0443 - val_loss: 0.9460 - val_mse: 0.9460
# Epoch 223/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0436 - mse: 1.0436 - val_loss: 0.9502 - val_mse: 0.9502
# Epoch 224/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0439 - mse: 1.0439 - val_loss: 0.9533 - val_mse: 0.9533
# Epoch 225/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0443 - mse: 1.0443 - val_loss: 0.9550 - val_mse: 0.9550
# Epoch 226/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0441 - mse: 1.0441 - val_loss: 0.9507 - val_mse: 0.9507
# Epoch 227/300
# 4/4 [==============================] - 0s 8ms/step - loss: 1.0435 - mse: 1.0435 - val_loss: 0.9493 - val_mse: 0.9493
# Epoch 228/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0438 - mse: 1.0438 - val_loss: 0.9497 - val_mse: 0.9497
# Epoch 229/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0440 - mse: 1.0440 - val_loss: 0.9569 - val_mse: 0.9569
# Epoch 230/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0452 - mse: 1.0452 - val_loss: 0.9555 - val_mse: 0.9555
# Epoch 231/300
# 4/4 [==============================] - 0s 8ms/step - loss: 1.0449 - mse: 1.0449 - val_loss: 0.9608 - val_mse: 0.9608
# Epoch 232/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0474 - mse: 1.0474 - val_loss: 0.9582 - val_mse: 0.9582
# Epoch 233/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0461 - mse: 1.0461 - val_loss: 0.9570 - val_mse: 0.9570
# Epoch 234/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0455 - mse: 1.0455 - val_loss: 0.9529 - val_mse: 0.9529
# Epoch 235/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0443 - mse: 1.0443 - val_loss: 0.9497 - val_mse: 0.9497
# Epoch 236/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0442 - mse: 1.0442 - val_loss: 0.9496 - val_mse: 0.9496
# Epoch 237/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0435 - mse: 1.0435 - val_loss: 0.9478 - val_mse: 0.9478
# Epoch 238/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0433 - mse: 1.0433 - val_loss: 0.9479 - val_mse: 0.9479
# Epoch 239/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0436 - mse: 1.0436 - val_loss: 0.9475 - val_mse: 0.9475
# Epoch 240/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0438 - mse: 1.0438 - val_loss: 0.9496 - val_mse: 0.9496
# Epoch 241/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0451 - mse: 1.0451 - val_loss: 0.9497 - val_mse: 0.9497
# Epoch 242/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0435 - mse: 1.0435 - val_loss: 0.9488 - val_mse: 0.9488
# Epoch 243/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0433 - mse: 1.0433 - val_loss: 0.9496 - val_mse: 0.9496
# Epoch 244/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0435 - mse: 1.0435 - val_loss: 0.9464 - val_mse: 0.9464
# Epoch 245/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0435 - mse: 1.0435 - val_loss: 0.9459 - val_mse: 0.9459
# Epoch 246/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0434 - mse: 1.0434 - val_loss: 0.9487 - val_mse: 0.9487
# Epoch 247/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0435 - mse: 1.0435 - val_loss: 0.9517 - val_mse: 0.9517
# Epoch 248/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0438 - mse: 1.0438 - val_loss: 0.9514 - val_mse: 0.9514
# Epoch 249/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0433 - mse: 1.0433 - val_loss: 0.9497 - val_mse: 0.9497
# Epoch 250/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0439 - mse: 1.0439 - val_loss: 0.9485 - val_mse: 0.9485
# Epoch 251/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0432 - mse: 1.0432 - val_loss: 0.9469 - val_mse: 0.9469
# Epoch 252/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0455 - mse: 1.0455 - val_loss: 0.9490 - val_mse: 0.9490
# Epoch 253/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0437 - mse: 1.0437 - val_loss: 0.9509 - val_mse: 0.9509
# Epoch 254/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0439 - mse: 1.0439 - val_loss: 0.9492 - val_mse: 0.9492
# Epoch 255/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0434 - mse: 1.0434 - val_loss: 0.9507 - val_mse: 0.9507
# Epoch 256/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0447 - mse: 1.0447 - val_loss: 0.9505 - val_mse: 0.9505
# Epoch 257/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0438 - mse: 1.0438 - val_loss: 0.9525 - val_mse: 0.9525
# Epoch 258/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0438 - mse: 1.0438 - val_loss: 0.9493 - val_mse: 0.9493
# Epoch 259/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0443 - mse: 1.0443 - val_loss: 0.9477 - val_mse: 0.9477
# Epoch 260/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0452 - mse: 1.0452 - val_loss: 0.9500 - val_mse: 0.9500
# Epoch 261/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0438 - mse: 1.0438 - val_loss: 0.9484 - val_mse: 0.9484
# Epoch 262/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0442 - mse: 1.0442 - val_loss: 0.9501 - val_mse: 0.9501
# Epoch 263/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0436 - mse: 1.0436 - val_loss: 0.9469 - val_mse: 0.9469
# Epoch 264/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0437 - mse: 1.0437 - val_loss: 0.9469 - val_mse: 0.9469
# Epoch 265/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0435 - mse: 1.0435 - val_loss: 0.9477 - val_mse: 0.9477
# Epoch 266/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0440 - mse: 1.0440 - val_loss: 0.9469 - val_mse: 0.9469
# Epoch 267/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0438 - mse: 1.0438 - val_loss: 0.9471 - val_mse: 0.9471
# Epoch 268/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0440 - mse: 1.0440 - val_loss: 0.9465 - val_mse: 0.9465
# Epoch 269/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0438 - mse: 1.0438 - val_loss: 0.9484 - val_mse: 0.9484
# Epoch 270/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0437 - mse: 1.0437 - val_loss: 0.9468 - val_mse: 0.9468
# Epoch 271/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0437 - mse: 1.0437 - val_loss: 0.9484 - val_mse: 0.9484
# Epoch 272/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0445 - mse: 1.0445 - val_loss: 0.9471 - val_mse: 0.9471
# Epoch 273/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0438 - mse: 1.0438 - val_loss: 0.9453 - val_mse: 0.9453
# Epoch 274/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0439 - mse: 1.0439 - val_loss: 0.9446 - val_mse: 0.9446
# Epoch 275/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0450 - mse: 1.0450 - val_loss: 0.9445 - val_mse: 0.9445
# Epoch 276/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0449 - mse: 1.0449 - val_loss: 0.9444 - val_mse: 0.9444
# Epoch 277/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0441 - mse: 1.0441 - val_loss: 0.9446 - val_mse: 0.9446
# Epoch 278/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0439 - mse: 1.0439 - val_loss: 0.9451 - val_mse: 0.9451
# Epoch 279/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0439 - mse: 1.0439 - val_loss: 0.9486 - val_mse: 0.9486
# Epoch 280/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0435 - mse: 1.0435 - val_loss: 0.9517 - val_mse: 0.9517
# Epoch 281/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0434 - mse: 1.0434 - val_loss: 0.9523 - val_mse: 0.9523
# Epoch 282/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0437 - mse: 1.0437 - val_loss: 0.9502 - val_mse: 0.9502
# Epoch 283/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0432 - mse: 1.0432 - val_loss: 0.9517 - val_mse: 0.9517
# Epoch 284/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0438 - mse: 1.0438 - val_loss: 0.9493 - val_mse: 0.9493
# Epoch 285/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0432 - mse: 1.0432 - val_loss: 0.9501 - val_mse: 0.9501
# Epoch 286/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0447 - mse: 1.0447 - val_loss: 0.9461 - val_mse: 0.9461
# Epoch 287/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0442 - mse: 1.0442 - val_loss: 0.9500 - val_mse: 0.9500
# Epoch 288/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0435 - mse: 1.0435 - val_loss: 0.9458 - val_mse: 0.9458
# Epoch 289/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0449 - mse: 1.0449 - val_loss: 0.9445 - val_mse: 0.9445
# Epoch 290/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0439 - mse: 1.0439 - val_loss: 0.9454 - val_mse: 0.9454
# Epoch 291/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0434 - mse: 1.0434 - val_loss: 0.9470 - val_mse: 0.9470
# Epoch 292/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0435 - mse: 1.0435 - val_loss: 0.9499 - val_mse: 0.9499
# Epoch 293/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0434 - mse: 1.0434 - val_loss: 0.9516 - val_mse: 0.9516
# Epoch 294/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0440 - mse: 1.0440 - val_loss: 0.9491 - val_mse: 0.9491
# Epoch 295/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0439 - mse: 1.0439 - val_loss: 0.9507 - val_mse: 0.9507
# Epoch 296/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0433 - mse: 1.0433 - val_loss: 0.9530 - val_mse: 0.9530
# Epoch 297/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0439 - mse: 1.0439 - val_loss: 0.9525 - val_mse: 0.9525
# Epoch 298/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0436 - mse: 1.0436 - val_loss: 0.9539 - val_mse: 0.9539
# Epoch 299/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0448 - mse: 1.0448 - val_loss: 0.9523 - val_mse: 0.9523
# Epoch 300/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0440 - mse: 1.0440 - val_loss: 0.9542 - val_mse: 0.9542

# %% [markdown]
# ### Results

# %%
# return weights and biases
model.get_weights()
# Out:
# [array([[1.7678756]], dtype=float32), array([0.86875975], dtype=float32)]

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 32/32 [==============================] - 0s 488us/step - loss: 0.9542 - mse: 0.9542
#
# Test loss: 0.9542456269264221
# Test accuracy: 0.9542456269264221

# %%
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 32/32 [==============================] - 0s 499us/step - loss: 0.0353 - mse: 0.0353
#
# Test loss: 0.03530769795179367
# Test accuracy: 0.03530769795179367

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Exercise 11.2

# %% [markdown]
# Given the function to fit:
# $$
# f(x)=4-3x-2x^2+3x^3
# $$
# for $x \in [-1,1]$, the exercise asks us to explore some of the main parameters and options of a neural network.
# The main question that arises when trying to solve a problem through a neural network is how should the network be structured in terms of number of neurons, number of layers, activation function and so on. Unfortunately, there is no analytical or easy answer and the main theorems in the field (e.g. universal approximation theorem) demonstrate the general capabilites of such networks but without giving advice about how to build a neuron structure for a specific problem. Therefore, the only path left is to experimentally try as many configurations as possible and to deduce some overall qualitative properties. Therefore, based on the results obtained with the code and plots below, here are the main conclusions that could be drawn:
#
# - **Network size: layer depth and width**:

# %%
#target parameters
def poly_func(x):
    a=4.
    b=-3.
    c=-2.
    d=3.
    
    return a + b*x + c*x**2 + d*x**3

# %%
# generate training inputs
np.random.seed(0)
n_train=1800
x_train = np.random.uniform(-1, 1, 1800)
x_valid = np.random.uniform(-1, 1, int(n_train/9))
x_valid.sort()
y_target = poly_func(x_valid)  # ideal (target) polinomial function

sigma = 0 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(poly_func(x_train), sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(poly_func(x_valid), sigma)

# %%
# plot validation and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target, label='target')
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(20, input_shape=(1,)))
#model.add(Dense(25,activation='relu'))
#model.add(Dense(25,activation='relu'))
#model.add(Dense(20,activation='relu'))
model.add(Dense(1,activation='relu'))


# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# get a summary of our composed model
model.summary()
# Out:
# Model: "sequential_58"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_196 (Dense)            (None, 200)               400
# _________________________________________________________________
# dense_197 (Dense)            (None, 1)                 201
# =================================================================
# Total params: 601
# Trainable params: 601
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=30,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid),verbose=0)

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()
print(f"final training loss: {history.history['loss'][-1]}\nfinal test loss: {history.history['val_loss'][-1]} ")
# Out:
# final training loss: 0.5663594007492065
# final test loss: 0.7225265502929688

# %% [markdown]
# ## esercizio3

# %%
#target parameters
def func(x,y):
    return (x**2+y**2)
    #np.sin(x**2+y**2)

# %%
# generate training inputs
np.random.seed(0)
p_train = np.random.uniform(-1.5, 1.5, size=(500,2))

p_valid = np.random.uniform(-1.5, 1.5, size=(50,2))

sigma = 0. # noise standard deviation, for the moment it is absent
z_train = np.random.normal(func(p_train[:,0],p_train[:,1]), sigma) # actual measures from which we want to guess regression parameters
z_valid = np.random.normal(func(p_valid[:,0],p_valid[:,1]), sigma)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create x, y coords
X, Y = np.meshgrid(np.linspace(-1.5,1.5,100),np.linspace(-1.5,1.5,100))

# dummy data
z_target = func(X,Y)  # ideal (target) polinomial function

# Create matplotlib Figure and Axes
fig = plt.figure(figsize=(10,10))
ax = Axes3D(fig)
ax.view_init(10,30)


# Plot the surface
ax.scatter(p_valid[:,0],p_valid[:,1], z_valid, label='validation points', color='red', depthshade='False')
ax.plot_surface(X,Y, z_target, label='target', alpha=0.2)


ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %%
model = Sequential()

model.add(Dense(20, input_dim=2, activation='tanh', kernel_initializer="uniform"))
model.add(Dense(1,activation='linear'))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='adam', loss='mse', metrics=['mse'])
          
model.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_62 (Dense)             (None, 20)                60
# _________________________________________________________________
# dense_63 (Dense)             (None, 1)                 21
# =================================================================
# Total params: 81
# Trainable params: 81
# Non-trainable params: 0
# _________________________________________________________________

# %%
p_train



history = model.fit(x=p_train, y=z_train, 
          batch_size=32, epochs=50,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(p_valid, z_valid), verbose=1)
# Out:
# Epoch 1/50
# 16/16 [==============================] - 0s 6ms/step - loss: 3.1037 - mse: 3.1037 - val_loss: 3.9046 - val_mse: 3.9046
# Epoch 2/50
# 16/16 [==============================] - 0s 2ms/step - loss: 2.8193 - mse: 2.8193 - val_loss: 3.5809 - val_mse: 3.5809
# Epoch 3/50
# 16/16 [==============================] - 0s 2ms/step - loss: 2.5273 - mse: 2.5273 - val_loss: 3.2518 - val_mse: 3.2518
# Epoch 4/50
# 16/16 [==============================] - 0s 2ms/step - loss: 2.2314 - mse: 2.2314 - val_loss: 2.8967 - val_mse: 2.8967
# Epoch 5/50
# 16/16 [==============================] - 0s 2ms/step - loss: 1.9378 - mse: 1.9378 - val_loss: 2.5805 - val_mse: 2.5805
# Epoch 6/50
# 16/16 [==============================] - 0s 2ms/step - loss: 1.6711 - mse: 1.6711 - val_loss: 2.2591 - val_mse: 2.2591
# Epoch 7/50
# 16/16 [==============================] - 0s 2ms/step - loss: 1.4342 - mse: 1.4342 - val_loss: 1.9990 - val_mse: 1.9990
# Epoch 8/50
# 16/16 [==============================] - 0s 2ms/step - loss: 1.2463 - mse: 1.2463 - val_loss: 1.7719 - val_mse: 1.7719
# Epoch 9/50
# 16/16 [==============================] - 0s 2ms/step - loss: 1.1110 - mse: 1.1110 - val_loss: 1.6054 - val_mse: 1.6054
# Epoch 10/50
# 16/16 [==============================] - 0s 1ms/step - loss: 1.0173 - mse: 1.0173 - val_loss: 1.4813 - val_mse: 1.4813
# Epoch 11/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9627 - mse: 0.9627 - val_loss: 1.3990 - val_mse: 1.3990
# Epoch 12/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9348 - mse: 0.9348 - val_loss: 1.3244 - val_mse: 1.3244
# Epoch 13/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9228 - mse: 0.9228 - val_loss: 1.2920 - val_mse: 1.2920
# Epoch 14/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9159 - mse: 0.9159 - val_loss: 1.2780 - val_mse: 1.2780
# Epoch 15/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9143 - mse: 0.9143 - val_loss: 1.2750 - val_mse: 1.2750
# Epoch 16/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9163 - mse: 0.9163 - val_loss: 1.2645 - val_mse: 1.2645
# Epoch 17/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9149 - mse: 0.9149 - val_loss: 1.2676 - val_mse: 1.2676
# Epoch 18/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9139 - mse: 0.9139 - val_loss: 1.2703 - val_mse: 1.2703
# Epoch 19/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9148 - mse: 0.9148 - val_loss: 1.2683 - val_mse: 1.2683
# Epoch 20/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9154 - mse: 0.9154 - val_loss: 1.2492 - val_mse: 1.2492
# Epoch 21/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9151 - mse: 0.9151 - val_loss: 1.2653 - val_mse: 1.2653
# Epoch 22/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9144 - mse: 0.9144 - val_loss: 1.2582 - val_mse: 1.2582
# Epoch 23/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9142 - mse: 0.9142 - val_loss: 1.2615 - val_mse: 1.2615
# Epoch 24/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9148 - mse: 0.9148 - val_loss: 1.2649 - val_mse: 1.2649
# Epoch 25/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9140 - mse: 0.9140 - val_loss: 1.2591 - val_mse: 1.2591
# Epoch 26/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9151 - mse: 0.9151 - val_loss: 1.2625 - val_mse: 1.2625
# Epoch 27/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9150 - mse: 0.9150 - val_loss: 1.2566 - val_mse: 1.2566
# Epoch 28/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9134 - mse: 0.9134 - val_loss: 1.2617 - val_mse: 1.2617
# Epoch 29/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9138 - mse: 0.9138 - val_loss: 1.2613 - val_mse: 1.2613
# Epoch 30/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9136 - mse: 0.9136 - val_loss: 1.2619 - val_mse: 1.2619
# Epoch 31/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9144 - mse: 0.9144 - val_loss: 1.2636 - val_mse: 1.2636
# Epoch 32/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9139 - mse: 0.9139 - val_loss: 1.2618 - val_mse: 1.2618
# Epoch 33/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9143 - mse: 0.9143 - val_loss: 1.2555 - val_mse: 1.2555
# Epoch 34/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9143 - mse: 0.9143 - val_loss: 1.2649 - val_mse: 1.2649
# Epoch 35/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9166 - mse: 0.9166 - val_loss: 1.2747 - val_mse: 1.2747
# Epoch 36/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9133 - mse: 0.9133 - val_loss: 1.2603 - val_mse: 1.2603
# Epoch 37/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9133 - mse: 0.9133 - val_loss: 1.2557 - val_mse: 1.2557
# Epoch 38/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9139 - mse: 0.9139 - val_loss: 1.2513 - val_mse: 1.2513
# Epoch 39/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9143 - mse: 0.9143 - val_loss: 1.2694 - val_mse: 1.2694
# Epoch 40/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9154 - mse: 0.9154 - val_loss: 1.2561 - val_mse: 1.2561
# Epoch 41/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9152 - mse: 0.9152 - val_loss: 1.2681 - val_mse: 1.2681
# Epoch 42/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9152 - mse: 0.9152 - val_loss: 1.2788 - val_mse: 1.2788
# Epoch 43/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9132 - mse: 0.9132 - val_loss: 1.2591 - val_mse: 1.2591
# Epoch 44/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9138 - mse: 0.9138 - val_loss: 1.2541 - val_mse: 1.2541
# Epoch 45/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9154 - mse: 0.9154 - val_loss: 1.2600 - val_mse: 1.2600
# Epoch 46/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9154 - mse: 0.9154 - val_loss: 1.2642 - val_mse: 1.2642
# Epoch 47/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9145 - mse: 0.9145 - val_loss: 1.2553 - val_mse: 1.2553
# Epoch 48/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9137 - mse: 0.9137 - val_loss: 1.2560 - val_mse: 1.2560
# Epoch 49/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9137 - mse: 0.9137 - val_loss: 1.2611 - val_mse: 1.2611
# Epoch 50/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9144 - mse: 0.9144 - val_loss: 1.2677 - val_mse: 1.2677

# %%
p_predicted = np.random.uniform(-1.5, 1.5, size=(10,2))
z_predicted = model.predict(p_predicted)



# Create matplotlib Figure and Axes
fig = plt.figure(figsize=(10,10))
ax = Axes3D(fig)
ax.view_init(0,90)


# Plot the surface
ax.scatter(p_predicted[:,0],p_predicted[:,1], z_predicted, label='prediction points', color='red', depthshade='False')
ax.plot_surface(X,Y, z_target, label='target', alpha=0.2)

#ax.set_zlim(0,1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd6707908c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
